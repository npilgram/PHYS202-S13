# %% [markdown]
# Midterm
# ===

# %% [markdown]
# Q2
# --

# %% [markdown]
# ###a.)

# %%
theta = arange(-pi, pi+0.1, 0.1)
y = (cos((2*theta))*cos((theta/2)))**2
plot(theta, y, label=r'$cos(2\theta)cos(\frac{\theta}{2})^{2}$', color='red')
xlabel(r'$\theta$', fontsize =20)
ylabel(r'$Intsity$', fontsize=20)
xticks(arange(-pi,pi+0.1, (pi/2)),('$-\pi$',r'$-\frac{\pi}{2}$','0',r'$+\frac{\pi}{2}$',r'$+\pi$'), fontsize=16)
legend(loc='upper left')
show()

# %%
plot(theta, y, "b*", label=r'$cos(2\theta)cos(\frac{\theta}{2})^{2}$')
xlabel(r'$\theta$', fontsize =20)
ylabel(r'$Intsity$', fontsize=20)
xticks(arange(-pi,pi+0.1, (pi/2)),('$-\pi$',r'$-\frac{\pi}{2}$','0',r'$+\frac{\pi}{2}$',r'$+\pi$'), fontsize=16)
legend(loc='upper left')
show()

# %% [markdown]
# ###b.)

# %%
f = lambda t: (1+t)/(t-1)
g = lambda t: exp(-t)
t = arange(-5,5,0.1)
axis([-5,5,-10,10])
plot(t, f(t), label='(1+t)/(t-1)', color='blue')
plot(t, g(t), label='exp(-t)', color='red', linestyle=':')
xlabel('time (seconds)')
ylabel('f(t), g(t)')
legend(loc='lower left')
show()

# %% [markdown]
# Q3
# --

# %% [markdown]
# ###a.)

# %%
def pointField(x,y,q,Xq,Yq):
    """Returns the tuple of the electric field compontents(E_x,E_y) of charge q at position (Xq,Yq), x and y are arrays"""
    k =  8.9875517873681764*10.**9. #Nm^2/C^2
    E_x = (k*q*(x-Xq))/((((x-Xq)**2)+((y-Yq)**2))**(1./2.))
    E_y = (k*q*(y-Yq))/((((x-Xq)**2)+((y-Yq)**2))**(1./2.))
    return (E_x,E_y)

# %% [markdown]
# ###b.)

# %%
import scipy.integrate as integrate

# %%
E = lambda x,y: pointField(x,y,(1.0*(10**(-6))), 3, 3)
x = arange(0.,4.,0.1)
y = arange(0.,4.,0.1)
integrate.quad(E(x,y), 1, 2)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-70-ddb416461f18> in <module>()
#       2 x = arange(0.,4.,0.1)
#       3 y = arange(0.,4.,0.1)
# ----> 4 integrate.quad(E(x,y), 1, 2)
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     245     if type(args) != type(()): args = (args,)
#     246     if (weight is None):
# --> 247         retval = _quad(func,a,b,args,full_output,epsabs,epsrel,limit,points)
#     248     else:
#     249         retval = _quad_weight(func,a,b,args,full_output,epsabs,epsrel,limlst,limit,maxp1,weight,wvar,wopts)
#
# ...

# %% [markdown]
# Q4
# ---

# %% [markdown]
# ###a.)

# %% [markdown]
# The Modified working code is

# %%
prefixes = 'JKLMNOPQ'
suffix = 'ack'

for letter in prefixes:
    if letter == 'O' or letter == 'Q':
        print letter + 'uack'
    else:
        print letter + suffix
# Out:
# Jack
# Kack
# Lack
# Mack
# Nack
# Ouack
# Pack
# Quack

# %% [markdown]
# The new code works correctly.

# %% [markdown]
# ###b.)

# %%
def is_anagram(s1,s2):
    """Returns all True if the two words are anagrams. If two words are not anagrams last return is False."""
    L=[]
    for i in s2:
        L.append(i)
    for i in s1:
        if (i in L) == True:
            print True
        else:
            print False
            break

# %%
print is_anagram('bot','tub')
# Out:
# True
# False
# None

# %%
is_anagram('bot','tob')
# Out:
# True
# True
# True

# %% [markdown]
# My two test cases worked so my function should be good.
