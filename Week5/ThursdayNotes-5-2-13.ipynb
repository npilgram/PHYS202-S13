# %% [markdown]
# Monte Carlo Integration
# ===

# %% [markdown]
# ##Example 1

# %%
f = lambda x: x**(0.5)+sin(x)

# %%
x= arange(0.,15.,0.001)

# %%
myplot = plot(x, f(x), lw=3)
ylabel(r'$x^{1/2} + \sin(x)$', fontsize=20)
xlabel(r'$x$', fontsize = 20)
xlim(0.,15.)

show()

# %% [markdown]
# ###Creat bounding box

# %%
xmin=1.7
xmax=12.4

#find the maximum of f within the boundry to set ymax
subx = x[logical_and((x>xmin),(x<xmax))]
ymax= max(f(subx))*1.05
ymin=0.

#replot the function
myplot = plot(x, f(x), lw=3)
xlim(0.,15.)

#plot the box
plot([xmin, xmin], [ymin, ymax], color='k', linestyle='--') #vertical left
plot([xmax, xmax], [ymin, ymax], color='k', linestyle='--') #vertical right
plot([xmin, xmax], [ymax, ymax], color='k', linestyle='--') #horizontal top

show()

# %%
#random_sample?

N=10000
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);

#replot the function
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

plot(samples_x[1:200], samples_y[1:200], '.')

#plot the box
plot([xmin, xmin], [ymin, ymax], color='k', linestyle='--') #vertical left
plot([xmax, xmax], [ymin, ymax], color='k', linestyle='--') #vertical right
plot([xmin, xmax], [ymax, ymax], color='k', linestyle='--') #horizontal top

show()

# %%
newmask = (samples_y < f(samples_x))

# %%
sum(newmask)
# Out:
# 6124

# %%
#replot the function
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

plot(samples_x[1:200], samples_y[1:200], '.')

#show the ones below the function in red
plot(samples_x[newmask[:200]], samples_y[newmask[:200]], 'r.')

#plot the box
plot([xmin, xmin], [ymin, ymax], color='k', linestyle='--') #vertical left
plot([xmax, xmax], [ymin, ymax], color='k', linestyle='--') #vertical right
plot([xmin, xmax], [ymax, ymax], color='k', linestyle='--') #horizontal top

show()

# %% [markdown]
# ###Compute the integral

# %%
I = (xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size
print I
# Out:
# 26.2709310976

# %% [markdown]
# ###Exact integral

# %%
Iana = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax) - Iana(xmin)
Ierr = 100* (Iexact - I)/Iexact
print "I_exact", Iexact
print "I_hitormiss", I
print "Error on I", Ierr, "%"
# Out:
# I_exact 26.5172145362
# I_hitormiss 26.2709310976
# Error on I 0.928768133955 %

# %% [markdown]
# Exercise 1
# ===

# %%
f = lambda x: x**(0.5)+sin(x)
x= arange(0.,15.,0.001)
xmin=1.7
xmax=12.4

#find the maximum of f within the boundry to set ymax
subx = x[logical_and((x>xmin),(x<xmax))]
ymax= max(f(subx))*1.05
ymin=0.
N=6e7
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);
newmask = (samples_y < f(samples_x))
I = (xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size
Iana = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax) - Iana(xmin)
Ierr = 100* (Iexact - I)/Iexact
print "I_exact", Iexact
print "I_hitormiss", I
print "Error on I", Ierr, "%"
# Out:
# I_exact 26.5172145362
# I_hitormiss 26.5171452896
# Error on I 0.000261138350867 %

# %% [markdown]
# I needed N=6*10**7 to get within 0.001%

# %% [markdown]
# Exercise 2
# ==

# %% [markdown]
# ###a.)

# %%
f = lambda x: x**(0.5)+sin(x)
x = arange(0.,15.,0.001)
xmin=1.7
xmax=12.4
N=10000
samples_x = xmin + (xmax-xmin)*random_sample(N)
s = 0 
for i in samples_x:
    s = s + f(i)
I_N = (xmax-xmin)*(1./N)*s
print I_N
# Out:
# 26.4140192101

# %% [markdown]
# ###b.)

# %%
f_ave = np.ones(x.size, dtype=float)*s*(1./N)
plot(x,f(x),lw=3)
plot(x, f_ave, lw=3)
show()

# %% [markdown]
# ###c.)

# %%
Iana = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax) - Iana(xmin)
percentError = 100*(Iexact-I_N)/Iexact
print "Error",percentError
# Out:
# Error 0.389163522133

# %% [markdown]
# This method is a little more accurate than the hit or miss method

# %% [markdown]
# Example 2
# ==

# %%
fxyz = lambda x,y,z: sqrt(x**2 + y**2 + z**2)
    
N=1e6
L=1.; W=1.; H=1.
x = L*random_sample(N); y = W*random_sample(N); z = H*random_sample(N)
IntMC = (L*W*H/N)*sum(fxyz(x,y,z))
